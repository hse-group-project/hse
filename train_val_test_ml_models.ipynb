# %% [markdown]
# ## Импорты библиотек

# %%
import os
import json
import pandas as pd
import numpy as np
from datetime import datetime

import optuna
import optuna.logging
optuna.logging.set_verbosity(optuna.logging.CRITICAL)

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

from utils.utils import connection, data_from_ticker, data_from_tpulse, data_from_macrofactors
import utils.config_ml as config_ml

# %% [markdown]
# ## Импорты глобальных переменных

# %%
ticker = config_ml.TICKER
left_date = config_ml.LEFT_DATE
right_date = config_ml.RIGHT_DATE
train_period = config_ml.TRAIN_PERIOD
val_period = config_ml.VAL_PERIOD
test_period = config_ml.TEST_PERIOD
step = config_ml.STEP
models = config_ml.MODELS
n_trials = config_ml.N_TRIALS
metric_optuna = config_ml.METRIC_OPTUNA
top_n_features = config_ml.TOP_N_FEATURES

# %% [markdown]
# ## Сбор фичей по тикеру по дням

# %%
def pack_all_data_for_ml_models(ticker: str, left_date: str, right_date: str, conn):


    tpulse_data = data_from_tpulse(ticker, left_date, right_date, conn)
    ticker_data = data_from_ticker(ticker, left_date, right_date, conn)
    macrofactor_data = data_from_macrofactors(ticker, left_date, right_date, conn)

    data = tpulse_data.merge(macrofactor_data, how='left', on=['dt', 'ticker']).merge(ticker_data, how='left', on=['dt', 'ticker'])
    data = data[~data['target'].isnull()]

    return data

data = pack_all_data_for_ml_models(ticker, left_date, right_date, connection())
data.tail(3)
# Out:
#            dt ticker  commentscount_sum  commentscount_mean  \
# 60 2025-08-30   SBER                482           10.255319
# 61 2025-08-31   SBER                553           10.843137
# 62 2025-09-01   SBER               1078            7.000000
#
#     commentscount_max  reactioncount_sum  reactioncount_mean  \
# 60                 73                784           16.680851
# 61                 62                902           17.686275
# 62                119               1688           10.961039
#
#     reactioncount_max  num_words_sum  num_words_mean  ...  \
# 60                120           7551      160.659574  ...
# 61                 61           8114      159.098039  ...
# 62                163          16145      104.837662  ...
#
#     high_lag_22_low_lag_22_diff_pct  high_low_diff  high_low_diff_pct  \
# 60                            3.175           0.83              0.268
# 61                            2.507           1.32              0.426
# 62                            1.721           3.68              1.192
#
#     open_lag_22_close_lag_22_diff  open_lag_22_close_lag_22_diff_pct  \
# 60                           2.82                              0.917
# 61                           3.21                              1.035
# 62                           3.29                              1.046
#
#     macd_lag_22  rsi_14_lag_22  boll_ub_lag_22  boll_lb_lag_22  target
# 60       -1.836         50.577         321.560         298.593  309.92
# 61       -1.265         55.439         319.949         299.389  310.99
# 62       -0.446         61.245         316.680         301.750  309.20
#
# [3 rows x 7622 columns]

# %% [markdown]
# ## Цикл ML

# %%
# Сохраните датафрейм сверху в .csv для удобства

df = data.copy()
df.to_csv(fr'{os.getcwd()}/all_features.csv', index=False)

df = pd.read_csv(fr'{os.getcwd()}/all_features.csv')
df = df[~df['target'].isnull()]
df.head()
# Out:
#            dt ticker  commentscount_sum  commentscount_mean  \
# 0  2025-07-01   SBER                467            5.494118
# 1  2025-07-02   SBER                570            6.867470
# 2  2025-07-03   SBER                547            8.287879
# 3  2025-07-04   SBER                528            9.777778
# 4  2025-07-05   SBER                437           15.607143
#
#    commentscount_max  reactioncount_sum  reactioncount_mean  \
# 0                 49               1382           16.258824
# 1                 47               1318           15.879518
# 2                 70                863           13.075758
# 3                 45               1269           23.500000
# 4                186                517           18.464286
#
#    reactioncount_max  num_words_sum  num_words_mean  ...  \
# 0                117          12947      152.317647  ...
# 1                114          10629      128.060241  ...
# 2                 50           8282      125.484848  ...
# 3                114           8157      151.055556  ...
# 4                 81           4818      172.071429  ...
#
#    high_lag_22_low_lag_22_diff_pct  high_low_diff  high_low_diff_pct  \
# 0                              NaN           3.30              1.043
# 1                              NaN           2.44              0.769
# 2                              NaN           2.76              0.866
# 3                            1.777           3.91              1.231
# 4                            1.870           1.10              0.344
#
#    open_lag_22_close_lag_22_diff  open_lag_22_close_lag_22_diff_pct  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                          -3.52                             -1.119
# 4                          -2.53                             -0.813
#
#    macd_lag_22  rsi_14_lag_22  boll_ub_lag_22  boll_lb_lag_22  target
# 0          NaN            NaN             NaN             NaN  318.42
# 1          NaN            NaN             NaN             NaN  319.43
# 2          NaN            NaN             NaN             NaN  319.17
# 3        0.000            NaN             NaN             NaN  319.44
# 4       -0.056            0.0         313.446         306.404  319.55
#
# [5 rows x 7622 columns]

# %%
# Кросс-валидация скользящим окном
def sliding_windows_cross_validatin(df, train_days, val_days, test_days, step):
    windows = []
    n = len(df)
    current_test_end = n
    while True:
        test_start = current_test_end - test_days
        if test_start < 0:
            break
        val_start = test_start - val_days
        if val_start < 0:
            break
        train_start = val_start - train_days
        if train_start < 0:
            break
        windows.append({'train': df.iloc[train_start:val_start],
                        'val': df.iloc[val_start:test_start],
                        'test': df.iloc[test_start:current_test_end],
                        'id': current_test_end,
                        'dates': {
                                    'train': (df['dt'].iloc[train_start], df['dt'].iloc[val_start-1]),
                                    'val': (df['dt'].iloc[val_start], df['dt'].iloc[test_start-1]),
                                    'test': (df['dt'].iloc[test_start], df['dt'].iloc[current_test_end-1])
                                }
                        })
        current_test_end -= step
        if current_test_end < train_days + val_days + test_days:
            break
    return windows[::-1]

# Отбор топ фичей
def select_top_features(model, feature_names, top_n):
    if hasattr(model, 'coef_') and len(model.coef_) > 0:
        coefs = np.abs(model.coef_)
        top_indices = np.argsort(coefs)[-top_n:]
    elif hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_
        top_indices = np.argsort(importances)[-top_n:]
    else:
        return feature_names[:top_n]
    return [feature_names[i] for i in top_indices]

# Подбор гиперпараметров
def make_objective(model_name, X_train, y_train, X_val, y_val):
    def objective(trial):
        model_cfg = models[model_name]
        params = {}
        if 'optuna_objective' in model_cfg and callable(model_cfg['optuna_objective']):
            params = model_cfg['optuna_objective'](trial)
        if model_name == 'CatBoost':
            model = CatBoostRegressor(**params, verbose=False)
        else:
            model = model_cfg['model']
            if params:
                model.set_params(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        if metric_optuna == 'MAPE':
            return mean_absolute_percentage_error(y_val, y_pred)
        elif metric_optuna == 'MAE':
            return mean_absolute_error(y_val, y_pred)
    return objective

# %%
# Цикл ML
def train_val_test_ml_models(df, windows, models):
    print(f'Запущен цикл разработки ML моделей для прогнозирования стоимости акций "{ticker}"\n')
    df_ml_db = pd.DataFrame(columns=['dt', 'ticker', 'left_date', 'right_date', 'model_name', 'model_value', 'train_period', 'val_period', 'test_period', 'step', 'mape_mean', 'mae_mean', 'best_features'])
    df_ml = pd.DataFrame(columns=['test_period', 'model_name', 'mape', 'mae'])
    for model in models:
        ml_info = [] # model, features, mape,
        for idx, window in enumerate(windows):
            train, val, test = window['train'], window['val'], window['test']
            feature_cols = [col for col in train.columns if col not in ['dt', 'ticker', 'target']]

            print(f'Окно {idx+1} / модель {model}')
            print(f"Обучение {len(window['train'])} дн. {window['dates']['train'][0]} - {window['dates']['train'][1]} / Валидация {len(window['val'])} дн. {window['dates']['val'][0]} - {window['dates']['val'][1]} / Тестирование {len(window['test'])} дн. {window['dates']['test'][0]} - {window['dates']['test'][1]}")

            if model in ['LinearRegression', 'DecisionTree', 'GradientBoosting']:
                train = train.fillna(0)
                val = val.fillna(0)
                test = test.fillna(0)

            # Деление на train/test/val
            X_train, y_train = train[feature_cols], train['target']
            X_val, y_val = val[feature_cols], val['target']
            X_test, y_test = test[feature_cols], test['target']

            # Для линейных моделей важно стандартизировать данные
            if model == 'LinearRegression':
                best_params = {}
                scaler = StandardScaler()
                X_train_scaled = scaler.fit_transform(X_train)
                X_test_scaled = scaler.transform(X_test)
            else:
                # Для нелинейных моделей поиск ГП с помощью Optuna
                objective = make_objective(model, X_train, y_train, X_val, y_val)
                study = optuna.create_study(direction='minimize')
                study.optimize(objective, n_trials=4)
                best_params = study.best_params
                print(f"Лучшие ГП модели: {best_params} c {metric_optuna}={study.best_value:.3f}")

            if model == 'CatBoost':
                best_optuna_model = CatBoostRegressor(**best_params, verbose=False)
            else:
                best_optuna_model = models[model]['model']
                best_optuna_model.set_params(**best_params)
            if model == 'LinearRegression':
                best_optuna_model.fit(X_train_scaled, y_train)
            else:
                best_optuna_model.fit(X_train, y_train)

            # Отбор топ фичей
            selected_features = select_top_features(best_optuna_model, feature_cols, top_n_features)
            print(f'Отобрано топ-{top_n_features} фичей, 5 лучших из них: {selected_features[:5]}')
            selected_idx = [feature_cols.index(feature) for feature in selected_features]

            # Тестирование модели с лучшими ГП только на топ фичах
            if model == 'LinearRegression':
                best_optuna_model.fit(X_train_scaled[:, selected_idx], y_train)
                y_test_pred = best_optuna_model.predict(X_test_scaled[:, selected_idx])
            else:
                best_optuna_model.fit(X_train[selected_features], y_train)
                y_test_pred = best_optuna_model.predict(X_test[selected_features])
            test_mape = mean_absolute_percentage_error(y_test, y_test_pred)
            test_mae = mean_absolute_error(y_test, y_test_pred)
            print(f'Метрики лучшей модели в данном окне: MAPE={test_mape:.3f}, MAE={test_mae:.2f}\n')
            ml_info.append([best_optuna_model, selected_features, test_mape])

        # Определение лучшей модели - ГП из модели из окна с минимальным mape, лучшие фичи - те, которые есть во всех окнах
        best_model = sorted(ml_info, key=lambda x: x[-1])[0][0]
        best_features = set(ml_info[0][1])
        for feature_list in ml_info[1:]:
            best_features.intersection_update(feature_list[1])
        best_features = list(best_features)
        print('Формируется лучшая модель из построенных ранее...')
        print(f'Лучшая {model} модель - {best_model} с фичами в количестве {len(best_features)} шт.')
        mape_mean, mae_mean = [], []

        # Расчет статистик
        for idx, window in enumerate(windows):
            train, val, test = window['train'], window['val'], window['test']
            X_train, y_train = train[best_features], train['target']
            X_test, y_test = test[best_features], test['target']
            best_model.fit(X_train, y_train)
            best_model_pred = best_model.predict(X_test)
            test_mape = mean_absolute_percentage_error(y_test, best_model_pred)
            test_mae = mean_absolute_error(y_test, best_model_pred)
            mape_mean.append(test_mape)
            mae_mean.append(test_mae)
            new_row = pd.Series([f"{window['dates']['test'][0]} - {window['dates']['test'][1]}", model, round(test_mape,3), round(test_mae,3)], index=df_ml.columns)
            df_ml = pd.concat([df_ml, new_row.to_frame().T], ignore_index=True)
            print(f'Окно {idx+1}: лучшая {model} модель имеет MAPE={test_mape:.3f} ({round(100*(ml_info[idx][-1] - test_mape)/ml_info[idx][-1])}% к модели на окне {idx+1} ранее), MAE={test_mae:.2f}')

        new_row_db = pd.Series([datetime.now().strftime('%Y-%m-%d %H:%M:%S'), ticker, left_date, right_date, model, str(best_model), train_period, val_period, test_period, step, float(round(np.mean(mape_mean),3)), float(round(np.mean(mae_mean),3)), json.dumps(best_features)], index=df_ml_db.columns)
        df_ml_db = pd.concat([df_ml_db, new_row_db.to_frame().T], ignore_index=True)
        print('------------------------------------------------------------------------------------------------------------')

    # Отправить в бд созданные лучшие модели
    df_ml_db.to_sql('ml_models_data', con=connection(), if_exists='append', index=False)

    return df_ml.sort_values(by=['test_period', 'mae']), df_ml_db

windows = sliding_windows_cross_validatin(df, train_period, val_period, test_period, step)
df_ml, df_ml_db = train_val_test_ml_models(df, windows, models)
df_ml
# Out:
# Запущен цикл разработки ML моделей для прогнозирования стоимости акций "SBER"
#
# Окно 1 / модель DecisionTree
# Обучение 21 дн. 2025-07-04 - 2025-07-24 / Валидация 14 дн. 2025-07-25 - 2025-08-11 / Тестирование 7 дн. 2025-08-12 - 2025-08-18
# Лучшие ГП модели: {'max_depth': 15, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': None} c MAPE=0.021
# Отобрано топ-500 фичей, 5 лучших из них: ['RTSI_open_lag_10', 'RTSI_open_rm_9', 'RTSI_open_lag_9', 'RTSI_open_rm_8', 'RTSI_open_lag_8']
# Метрики лучшей модели в данном окне: MAPE=0.010, MAE=3.13
#
# Окно 2 / модель DecisionTree
# Обучение 21 дн. 2025-07-11 - 2025-07-31 / Валидация 14 дн. 2025-08-01 - 2025-08-18 / Тестирование 7 дн. 2025-08-19 - 2025-08-25
# Лучшие ГП модели: {'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_features': 'sqrt'} c MAPE=0.017
# Отобрано топ-500 фичей, 5 лучших из них: ['RTSI_open_lag_10', 'RTSI_open_rm_9', 'RTSI_open_lag_9', 'RTSI_open_rm_8', 'RTSI_open_lag_8']
# Метрики лучшей модели в данном окне: MAPE=0.005, MAE=1.62
#
# Окно 3 / модель DecisionTree
# Обучение 21 дн. 2025-07-18 - 2025-08-11 / Валидация 14 дн. 2025-08-12 - 2025-08-25 / Тестирование 7 дн. 2025-08-26 - 2025-09-01
# Лучшие ГП модели: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2'} c MAPE=0.010
# Отобрано топ-500 фичей, 5 лучших из них: ['RTSI_open_lag_9', 'RTSI_open_rm_8', 'RTSI_open_lag_8', 'RTSI_open_rm_7', 'RTSI_open_lag_7']
# Метрики лучшей модели в данном окне: MAPE=0.007, MAE=2.08
#
# Формируется лучшая модель из построенных ранее...
# Лучшая DecisionTree модель - DecisionTreeRegressor(max_depth=11, max_features='log2', min_samples_leaf=5,
#                       min_samples_split=4, random_state=42) с фичами в количестве 496 шт.
# Окно 1: лучшая DecisionTree модель имеет MAPE=0.016 (-62% к модели на окне 1 ранее), MAE=5.06
# Окно 2: лучшая DecisionTree модель имеет MAPE=0.009 (-74% к модели на окне 2 ранее), MAE=2.82
# Окно 3: лучшая DecisionTree модель имеет MAPE=0.011 (-60% к модели на окне 3 ранее), MAE=3.35
# ------------------------------------------------------------------------------------------------------------
# Окно 1 / модель RandomForest
# Обучение 21 дн. 2025-07-04 - 2025-07-24 / Валидация 14 дн. 2025-07-25 - 2025-08-11 / Тестирование 7 дн. 2025-08-12 - 2025-08-18
# Лучшие ГП модели: {'n_estimators': 258, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 0.6507607664914639, 'bootstrap': False} c MAPE=0.015
# Отобрано топ-500 фичей, 5 лучших из них: ['RTSI_open_rm_2', 'RTSI_open_lag_2', 'RTSI_open_lag_1', 'RTSFN_open_rm_22', 'RTSFN_open_lag_22']
# Метрики лучшей модели в данном окне: MAPE=0.006, MAE=1.75
#
# Окно 2 / модель RandomForest
# Обучение 21 дн. 2025-07-11 - 2025-07-31 / Валидация 14 дн. 2025-08-01 - 2025-08-18 / Тестирование 7 дн. 2025-08-19 - 2025-08-25
# Лучшие ГП модели: {'n_estimators': 134, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 0.418980008765036, 'bootstrap': False} c MAPE=0.014
# Отобрано топ-500 фичей, 5 лучших из них: ['RUPAI_open_rm_22', 'RUPAI_open_lag_22', 'RUPAI_open_rm_21', 'RUPAI_open_lag_21', 'RUPAI_open_rm_20']
# Метрики лучшей модели в данном окне: MAPE=0.009, MAE=2.72
#
# Окно 3 / модель RandomForest
# Обучение 21 дн. 2025-07-18 - 2025-08-11 / Валидация 14 дн. 2025-08-12 - 2025-08-25 / Тестирование 7 дн. 2025-08-26 - 2025-09-01
# Лучшие ГП модели: {'n_estimators': 154, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.7147304311778248, 'bootstrap': True} c MAPE=0.014
# Отобрано топ-500 фичей, 5 лучших из них: ['MIPO_open_lag_4', 'RTSI_close_lag_22', 'RTSI_close_lag_19', 'high_lag_8_low_lag_8_diff', 'IMOEX2_close_rm_14']
# Метрики лучшей модели в данном окне: MAPE=0.003, MAE=0.91
#
# Формируется лучшая модель из построенных ранее...
# Лучшая RandomForest модель - RandomForestRegressor(max_depth=9, max_features=0.7147304311778248,
#                       min_samples_leaf=2, n_estimators=154, n_jobs=-1,
#                       random_state=42) с фичами в количестве 17 шт.
# Окно 1: лучшая RandomForest модель имеет MAPE=0.004 (33% к модели на окне 1 ранее), MAE=1.17
# Окно 2: лучшая RandomForest модель имеет MAPE=0.010 (-11% к модели на окне 2 ранее), MAE=3.03
# Окно 3: лучшая RandomForest модель имеет MAPE=0.007 (-132% к модели на окне 3 ранее), MAE=2.11
# ------------------------------------------------------------------------------------------------------------
# Окно 1 / модель XGBoost
# Обучение 21 дн. 2025-07-04 - 2025-07-24 / Валидация 14 дн. 2025-07-25 - 2025-08-11 / Тестирование 7 дн. 2025-08-12 - 2025-08-18
# Лучшие ГП модели: {'n_estimators': 244, 'learning_rate': 0.013628495195903059, 'max_depth': 5, 'subsample': 0.8890779564966695, 'colsample_bytree': 0.7286668451278765, 'reg_alpha': 0.5982764343088715, 'reg_lambda': 0.9964590807026654} c MAPE=0.015
# Отобрано топ-500 фичей, 5 лучших из них: ['RUPCI_open_lag_16', 'RUPCI_open_lag_15', 'RUPAI_open_lag_21', 'RUPAI_open_rm_20', 'RUPAI_open_lag_20']
# Метрики лучшей модели в данном окне: MAPE=0.006, MAE=1.92
#
# Окно 2 / модель XGBoost
# Обучение 21 дн. 2025-07-11 - 2025-07-31 / Валидация 14 дн. 2025-08-01 - 2025-08-18 / Тестирование 7 дн. 2025-08-19 - 2025-08-25
# Лучшие ГП модели: {'n_estimators': 225, 'learning_rate': 0.13986245517069865, 'max_depth': 8, 'subsample': 0.7118951130157214, 'colsample_bytree': 0.9580892267693222, 'reg_alpha': 0.7019016601950809, 'reg_lambda': 0.3382796157423039} c MAPE=0.013
# Отобрано топ-500 фичей, 5 лучших из них: ['RUPAI_open_lag_11', 'RUPAI_open_rm_10', 'RUPAI_open_lag_10', 'RUPAI_open_rm_9', 'RUPAI_open_lag_9']
# Метрики лучшей модели в данном окне: MAPE=0.011, MAE=3.59
#
# Окно 3 / модель XGBoost
# Обучение 21 дн. 2025-07-18 - 2025-08-11 / Валидация 14 дн. 2025-08-12 - 2025-08-25 / Тестирование 7 дн. 2025-08-26 - 2025-09-01
# Лучшие ГП модели: {'n_estimators': 116, 'learning_rate': 0.09017158799910072, 'max_depth': 4, 'subsample': 0.9205774967114785, 'colsample_bytree': 0.9697993814791485, 'reg_alpha': 0.4940654311515662, 'reg_lambda': 0.23941773661069732} c MAPE=0.009
# Отобрано топ-500 фичей, 5 лучших из них: ['RUPMI_open_rm_13', 'RUPMI_open_lag_13', 'RUPMI_open_rm_12', 'RUPMI_open_lag_12', 'RUPMI_open_lag_18']
# Метрики лучшей модели в данном окне: MAPE=0.008, MAE=2.50
#
# Формируется лучшая модель из построенных ранее...
# Лучшая XGBoost модель - XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9697993814791485, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.09017158799910072,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=116, n_jobs=-1,
#              num_parallel_tree=None, ...) с фичами в количестве 382 шт.
# Окно 1: лучшая XGBoost модель имеет MAPE=0.015 (-155% к модели на окне 1 ранее), MAE=4.89
# Окно 2: лучшая XGBoost модель имеет MAPE=0.016 (-39% к модели на окне 2 ранее), MAE=4.98
# Окно 3: лучшая XGBoost модель имеет MAPE=0.011 (-33% к модели на окне 3 ранее), MAE=3.33
# ------------------------------------------------------------------------------------------------------------
# Окно 1 / модель LightGBM
# Обучение 21 дн. 2025-07-04 - 2025-07-24 / Валидация 14 дн. 2025-07-25 - 2025-08-11 / Тестирование 7 дн. 2025-08-12 - 2025-08-18
# Лучшие ГП модели: {'n_estimators': 136, 'learning_rate': 0.026163130592780304, 'max_depth': 3, 'num_leaves': 14, 'subsample': 0.8865694217925291, 'colsample_bytree': 0.9575338033184945} c MAPE=0.021
# Отобрано топ-500 фичей, 5 лучших из них: ['RTSI_open_lag_10', 'RTSI_open_rm_9', 'RTSI_open_lag_9', 'RTSI_open_rm_8', 'RTSI_open_lag_8']
# Метрики лучшей модели в данном окне: MAPE=0.010, MAE=3.13
#
# Окно 2 / модель LightGBM
# Обучение 21 дн. 2025-07-11 - 2025-07-31 / Валидация 14 дн. 2025-08-01 - 2025-08-18 / Тестирование 7 дн. 2025-08-19 - 2025-08-25
# Лучшие ГП модели: {'n_estimators': 231, 'learning_rate': 0.05257409083367341, 'max_depth': 3, 'num_leaves': 36, 'subsample': 0.8051920952410964, 'colsample_bytree': 0.8252568334257182} c MAPE=0.017
# Отобрано топ-500 фичей, 5 лучших из них: ['RTSI_open_lag_10', 'RTSI_open_rm_9', 'RTSI_open_lag_9', 'RTSI_open_rm_8', 'RTSI_open_lag_8']
# Метрики лучшей модели в данном окне: MAPE=0.005, MAE=1.62
#
# Окно 3 / модель LightGBM
# Обучение 21 дн. 2025-07-18 - 2025-08-11 / Валидация 14 дн. 2025-08-12 - 2025-08-25 / Тестирование 7 дн. 2025-08-26 - 2025-09-01
# Лучшие ГП модели: {'n_estimators': 205, 'learning_rate': 0.07063280728098015, 'max_depth': 9, 'num_leaves': 14, 'subsample': 0.8846654073103376, 'colsample_bytree': 0.9598356966412356} c MAPE=0.017
# Отобрано топ-500 фичей, 5 лучших из них: ['RTSI_open_lag_10', 'RTSI_open_rm_9', 'RTSI_open_lag_9', 'RTSI_open_rm_8', 'RTSI_open_lag_8']
# Метрики лучшей модели в данном окне: MAPE=0.004, MAE=1.29
#
# Формируется лучшая модель из построенных ранее...
# Лучшая LightGBM модель - LGBMRegressor(colsample_bytree=0.9598356966412356,
#               learning_rate=0.07063280728098015, max_depth=9, n_estimators=205,
#               n_jobs=-1, num_leaves=14, random_state=42,
#               subsample=0.8846654073103376, verbose=-1) с фичами в количестве 500 шт.
# Окно 1: лучшая LightGBM модель имеет MAPE=0.010 (0% к модели на окне 1 ранее), MAE=3.13
# Окно 2: лучшая LightGBM модель имеет MAPE=0.005 (0% к модели на окне 2 ранее), MAE=1.62
# Окно 3: лучшая LightGBM модель имеет MAPE=0.004 (0% к модели на окне 3 ранее), MAE=1.29
# ------------------------------------------------------------------------------------------------------------
# Окно 1 / модель CatBoost
# Обучение 21 дн. 2025-07-04 - 2025-07-24 / Валидация 14 дн. 2025-07-25 - 2025-08-11 / Тестирование 7 дн. 2025-08-12 - 2025-08-18
# Лучшие ГП модели: {'iterations': 226, 'learning_rate': 0.12206561857730769, 'depth': 8, 'l2_leaf_reg': 9.311855796401908, 'border_count': 60} c MAPE=0.017
# Отобрано топ-500 фичей, 5 лучших из них: ['high_rm_3', 'MOEX10_close_lag_1', 'RTSIT_close_lag_6', 'tfidf_зона_max', 'tfidf_высоко_sum']
# Метрики лучшей модели в данном окне: MAPE=0.009, MAE=2.76
#
# Окно 2 / модель CatBoost
# Обучение 21 дн. 2025-07-11 - 2025-07-31 / Валидация 14 дн. 2025-08-01 - 2025-08-18 / Тестирование 7 дн. 2025-08-19 - 2025-08-25
# Лучшие ГП модели: {'iterations': 191, 'learning_rate': 0.0869387345473732, 'depth': 3, 'l2_leaf_reg': 9.625825292138325, 'border_count': 33} c MAPE=0.017
# Отобрано топ-500 фичей, 5 лучших из них: ['RUCBTRNS_open_lag_13', 'RUCBTRNS_open_rm_12', 'RUCBTRNS_open_lag_12', 'RUCBTRNS_open_rm_11', 'RUCBTRNS_open_rm_15']
# Метрики лучшей модели в данном окне: MAPE=0.008, MAE=2.38
#
# Окно 3 / модель CatBoost
# Обучение 21 дн. 2025-07-18 - 2025-08-11 / Валидация 14 дн. 2025-08-12 - 2025-08-25 / Тестирование 7 дн. 2025-08-26 - 2025-09-01
# Лучшие ГП модели: {'iterations': 170, 'learning_rate': 0.04178891148437538, 'depth': 4, 'l2_leaf_reg': 3.1396126069157715, 'border_count': 111} c MAPE=0.009
# Отобрано топ-500 фичей, 5 лучших из них: ['MOEXFN_close_lag_9', 'EPSITR_close_lag_14', 'EPSITR_close_rm_5', 'tfidf_отскок_max', 'BPSI_close_rm_19']
# Метрики лучшей модели в данном окне: MAPE=0.005, MAE=1.46
#
# Формируется лучшая модель из построенных ранее...
# Лучшая CatBoost модель - <catboost.core.CatBoostRegressor object at 0x30cc7b710> с фичами в количестве 6 шт.
# Окно 1: лучшая CatBoost модель имеет MAPE=0.005 (42% к модели на окне 1 ранее), MAE=1.60
# Окно 2: лучшая CatBoost модель имеет MAPE=0.004 (46% к модели на окне 2 ранее), MAE=1.28
# Окно 3: лучшая CatBoost модель имеет MAPE=0.004 (8% к модели на окне 3 ранее), MAE=1.34
# ------------------------------------------------------------------------------------------------------------
#                 test_period    model_name   mape    mae
# 3   2025-08-12 - 2025-08-18  RandomForest  0.004  1.175
# 12  2025-08-12 - 2025-08-18      CatBoost  0.005  1.604
# 9   2025-08-12 - 2025-08-18      LightGBM   0.01   3.13
# 6   2025-08-12 - 2025-08-18       XGBoost  0.015  4.895
# 0   2025-08-12 - 2025-08-18  DecisionTree  0.016  5.063
# 13  2025-08-19 - 2025-08-25      CatBoost  0.004   1.28
# 10  2025-08-19 - 2025-08-25      LightGBM  0.005   1.62
# 1   2025-08-19 - 2025-08-25  DecisionTree  0.009  2.819
# 4   2025-08-19 - 2025-08-25  RandomForest   0.01   3.03
# 7   2025-08-19 - 2025-08-25       XGBoost  0.016   4.98
# 11  2025-08-26 - 2025-09-01      LightGBM  0.004  1.288
# 14  2025-08-26 - 2025-09-01      CatBoost  0.004  1.345
# 5   2025-08-26 - 2025-09-01  RandomForest  0.007  2.108
# 8   2025-08-26 - 2025-09-01       XGBoost  0.011   3.33
# 2   2025-08-26 - 2025-09-01  DecisionTree  0.011  3.351

# %%
df_ml_db
# Out:
#                     dt ticker   left_date  right_date    model_name  \
# 0  2025-12-02 22:15:13   SBER  2025-07-01  2025-09-01  DecisionTree
# 1  2025-12-02 22:15:16   SBER  2025-07-01  2025-09-01  RandomForest
# 2  2025-12-02 22:15:45   SBER  2025-07-01  2025-09-01       XGBoost
# 3  2025-12-02 22:15:45   SBER  2025-07-01  2025-09-01      LightGBM
# 4  2025-12-02 22:16:50   SBER  2025-07-01  2025-09-01      CatBoost
#
#                                          model_value train_period val_period  \
# 0  DecisionTreeRegressor(max_depth=11, max_featur...           21         14
# 1  RandomForestRegressor(max_depth=9, max_feature...           21         14
# 2  XGBRegressor(base_score=None, booster=None, ca...           21         14
# 3  LGBMRegressor(colsample_bytree=0.9598356966412...           21         14
# 4  <catboost.core.CatBoostRegressor object at 0x3...           21         14
#
#   test_period step mape_mean mae_mean  \
# 0           7    7     0.012    3.744
# 1           7    7     0.007    2.104
# 2           7    7     0.014    4.402
# 3           7    7     0.006    2.012
# 4           7    7     0.004     1.41
#
#                                        best_features
# 0  ["RUMBTRNS_open_rm_13", "RUPAI_open_lag_14", "...
# 1  ["RTSTN_open_lag_21", "RUCBTRNS_open_lag_10", ...
# 2  ["RUMBTRNS_open_rm_13", "num_words_sum", "comm...
# 3  ["RUMBTRNS_open_rm_13", "RUPAI_open_lag_14", "...
# 4  ["open", "open_lag_21", "MOEXBMI_close_rm_3", ...
